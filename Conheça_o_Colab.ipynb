# %% [markdown]
# <a href="https://colab.research.google.com/github/xandebrian009-code/Engenharia-prompt-aplicaoes-em-ia/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conheça o Colab

# %%
numeros = [10,20,30,40,50]
i = 0

while i < len (numeros):
    soma += numeros [i]
    i += 1

print("soma total:", soma)
# Out:
# soma total: 300

# %%
def eh_primo(n):
  for i in range(2, n):
    if n % i == 0:
      return false
